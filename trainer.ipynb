# %%
# train_yolov8m_p2_se.py
# Запуск:  python train_yolov8m_p2_se.py
from ultralytics import YOLO

# ──────────────────────────────────────────────────────────────────────────────
# 1.  Подготовка модели
# ──────────────────────────────────────────────────────────────────────────────
model_cfg = "yolov8m_p2_se.yaml"
data_cfg  = "../pt_to_hef_converter/manipulator_project_datasets/data.yaml"
device    = 0

# ──────────────────────────────────────────────────────────────────────────────
# 2.  Гиперпараметры (тюнинг под 640²)
# ──────────────────────────────────────────────────────────────────────────────
train_args = dict(
    imgsz          = 640,    # фиксированный input-size
    epochs         = 30,    # чуть дольше, чтобы компенсировать меньшее разрешение
    batch          = 11,     # под 12-16 GB VRAM (при 24 GB можно 32)
    workers        = 8,      # подберите под CPU
    device         = device,
    
    # оптимизатор & LR-sched
    optimizer      = "SGD",      # SGD стабилен на больших эпохах
    lr0            = 0.005,      # старт LR (чуть ниже дефолта)
    lrf            = 0.01,       # конечный LR (cosine decay)
    momentum       = 0.9,
    weight_decay   = 5e-4,
    
    # Augmentations
    mosaic         = 1.0,        # включён (по умолч.)
    mixup          = 0.2,
    hsv_h          = 0.015,      # лёгкие цветовые
    hsv_s          = 0.7,
    hsv_v          = 0.4,
    flipud         = 0.0,
    fliplr         = 0.5,
    scale          = 0.7,        # ↑ увеличили диапазон масштабирования
    degrees        = 0.0,
    translate      = 0.1,
    
    # EMA и early-stopping
    patience       = 50,         # ранняя остановка, если val-mAP не растёт
    save_period    = 10,         # чекпоинт каждые 10 эпох
    seed           = 0,
    
    # Mixed precision
    amp            = True,       # fp16 → быстрее и меньше VRAM
    project        = 'runs/train',
    name           = 'custom_yolo_experiment',
    save           = True,
    plots          = True,
    val            = True,
)

# ──────────────────────────────────────────────────────────────────────────────
# 3.  Запуск обучения
# ──────────────────────────────────────────────────────────────────────────────
if __name__ == "__main__":
    model = YOLO(model_cfg)
    model.train(data=data_cfg, **train_args)
# Out:
# DEBUG: Creating ConvSE with args: [3, 48, 3, 2]
# DEBUG: Arg types: ['int', 'int', 'int', 'int']
# DEBUG: Creating ConvSE with args: [48, 96, 3, 2]
# DEBUG: Arg types: ['int', 'int', 'int', 'int']
# DEBUG: Creating C2f with args: [96, 96, 2, True, <class 'ultralytics.nn.modules.custom_modules.ConvSE'>]
# DEBUG: Arg types: ['int', 'int', 'int', 'bool', 'type']
# DEBUG: Creating ConvSE with args: [96, 192, 3, 2]
# DEBUG: Arg types: ['int', 'int', 'int', 'int']
# DEBUG: Creating C2f with args: [192, 192, 4, True, <class 'ultralytics.nn.modules.custom_modules.ConvSE'>]
# DEBUG: Arg types: ['int', 'int', 'int', 'bool', 'type']
# DEBUG: Creating ConvSE with args: [192, 384, 3, 2]
# DEBUG: Arg types: ['int', 'int', 'int', 'int']
# DEBUG: Creating C2f with args: [384, 384, 4, True, <class 'ultralytics.nn.modules.custom_modules.ConvSE'>]
# DEBUG: Arg types: ['int', 'int', 'int', 'bool', 'type']
# DEBUG: Creating ConvSE with args: [384, 576, 3, 2]
# DEBUG: Arg types: ['int', 'int', 'int', 'int']
# DEBUG: Creating C2f with args: [576, 576, 2, True, <class 'ultralytics.nn.modules.custom_modules.ConvSE'>]
# DEBUG: Arg types: ['int', 'int', 'int', 'bool', 'type']
# DEBUG: Creating SPPF with args: [576, 576, 7]
# DEBUG: Arg types: ['int', 'int', 'int']
# DEBUG: Creating Upsample with args: [None, 2, 'nearest']
# DEBUG: Arg types: ['NoneType', 'int', 'str']
# DEBUG: Creating Concat with args: [1]
# DEBUG: Arg types: ['int']
# DEBUG: Creating C2f with args: [960, 384, 2, False, <class 'ultralytics.nn.modules.custom_modules.ConvSE'>]
# DEBUG: Arg types: ['int', 'int', 'int', 'bool', 'type']
# DEBUG: Creating Upsample with args: [None, 2, 'nearest']
# DEBUG: Arg types: ['NoneType', 'int', 'str']
# DEBUG: Creating Concat with args: [1]
# DEBUG: Arg types: ['int']
# DEBUG: Creating C2f with args: [576, 192, 2, False, <class 'ultralytics.nn.modules.custom_modules.ConvSE'>]
# DEBUG: Arg types: ['int', 'int', 'int', 'bool', 'type']
# DEBUG: Creating Upsample with args: [None, 2, 'nearest']
# DEBUG: Arg types: ['NoneType', 'int', 'str']
# DEBUG: Creating Concat with args: [1]
# DEBUG: Arg types: ['int']
# DEBUG: Creating C2f with args: [288, 96, 1, False, <class 'ultralytics.nn.modules.custom_modules.ConvSE'>]
# DEBUG: Arg types: ['int', 'int', 'int', 'bool', 'type']
# DEBUG: Creating ConvSE with args: [96, 96, 3, 2]
# DEBUG: Arg types: ['int', 'int', 'int', 'int']
# DEBUG: Creating Concat with args: [1]
# DEBUG: Arg types: ['int']
# DEBUG: Creating C2f with args: [288, 192, 1, False, <class 'ultralytics.nn.modules.custom_modules.ConvSE'>]
# DEBUG: Arg types: ['int', 'int', 'int', 'bool', 'type']
# DEBUG: Creating ConvSE with args: [192, 192, 3, 2]
# DEBUG: Arg types: ['int', 'int', 'int', 'int']
# DEBUG: Creating Concat with args: [1]
# DEBUG: Arg types: ['int']
# DEBUG: Creating C2f with args: [576, 384, 1, False, <class 'ultralytics.nn.modules.custom_modules.ConvSE'>]
# DEBUG: Arg types: ['int', 'int', 'int', 'bool', 'type']
# DEBUG: Creating ConvSE with args: [384, 384, 3, 2]
# DEBUG: Arg types: ['int', 'int', 'int', 'int']
# DEBUG: Creating Concat with args: [1]
# DEBUG: Arg types: ['int']
# DEBUG: Creating C2f with args: [960, 576, 1, False, <class 'ultralytics.nn.modules.custom_modules.ConvSE'>]
# DEBUG: Arg types: ['int', 'int', 'int', 'bool', 'type']
# DEBUG: Creating Detect_HailoFriendly with args: [14, [96, 192, 384, 576]]
# DEBUG: Arg types: ['int', 'list']
# New https://pypi.org/project/ultralytics/8.3.161 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.160 🚀 Python-3.10.18 torch-2.7.1+cu126 CUDA:0 (NVIDIA GeForce RTX 4070 Laptop GPU, 7933MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=11, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=../pt_to_hef_converter/manipulator_project_datasets/data.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=30, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.005, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.2, mode=train, model=yolov8m_p2_se.yaml, momentum=0.9, mosaic=1.0, multi_scale=False, name=custom_yolo_experiment32, nbs=64, nms=False, opset=None, optimize=False, optimizer=SGD, overlap_mask=True, patience=50, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=runs/train, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=runs/train/custom_yolo_experiment32, save_frames=False, save_json=False, save_period=10, save_txt=False, scale=0.7, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
#
#                    from  n    params  module                                       arguments
# DEBUG: Creating ConvSE with args: [3, 48, 3, 2]
# DEBUG: Arg types: ['int', 'int', 'int', 'int']
#   0                  -1  1      1731  ultralytics.nn.modules.custom_modules.ConvSE [3, 48, 3, 2]
# DEBUG: Creating ConvSE with args: [48, 96, 3, 2]
# DEBUG: Arg types: ['int', 'int', 'int', 'int']
#   1                  -1  1     42918  ultralytics.nn.modules.custom_modules.ConvSE [48, 96, 3, 2]
# DEBUG: Creating C2f with args: [96, 96, 2, True, <class 'ultralytics.nn.modules.custom_modules.ConvSE'>]
# DEBUG: Arg types: ['int', 'int', 'int', 'bool', 'type']
#   2                  -1  2     70374  ultralytics.nn.modules.block.C2f             [96, 96, 2, True, <class 'ultralytics.nn.modules.custom_modules.ConvSE'>]
# DEBUG: Creating ConvSE with args: [96, 192, 3, 2]
# DEBUG: Arg types: ['int', 'int', 'int', 'int']
#   3                  -1  1    171084  ultralytics.nn.modules.custom_modules.ConvSE [96, 192, 3, 2]
# DEBUG: Creating C2f with args: [192, 192, 4, True, <class 'ultralytics.nn.modules.custom_modules.ConvSE'>]
# DEBUG: Arg types: ['int', 'int', 'int', 'bool', 'type']
#   4                  -1  4    485784  ultralytics.nn.modules.block.C2f             [192, 192, 4, True, <class 'ultralytics.nn.modules.custom_modules.ConvSE'>]
# DEBUG: Creating ConvSE with args: [192, 384, 3, 2]
# DEBUG: Arg types: ['int', 'int', 'int', 'int']
#   5                  -1  1    683160  ultralytics.nn.modules.custom_modules.ConvSE [192, 384, 3, 2]
# DEBUG: Creating C2f with args: [384, 384, 4, True, <class 'ultralytics.nn.modules.custom_modules.ConvSE'>]
# DEBUG: Arg types: ['int', 'int', 'int', 'bool', 'type']
#   6                  -1  4   1939248  ultralytics.nn.modules.block.C2f             [384, 384, 4, True, <class 'ultralytics.nn.modules.custom_modules.ConvSE'>]
# DEBUG: Creating ConvSE with args: [384, 576, 3, 2]
# DEBUG: Arg types: ['int', 'int', 'int', 'int']
#   7                  -1  1   2033892  ultralytics.nn.modules.custom_modules.ConvSE [384, 576, 3, 2]
# DEBUG: Creating C2f with args: [576, 576, 2, True, <class 'ultralytics.nn.modules.custom_modules.ConvSE'>]
# DEBUG: Arg types: ['int', 'int', 'int', 'bool', 'type']
#   8                  -1  2   2513124  ultralytics.nn.modules.block.C2f             [576, 576, 2, True, <class 'ultralytics.nn.modules.custom_modules.ConvSE'>]
# DEBUG: Creating SPPF with args: [576, 576, 7]
# DEBUG: Arg types: ['int', 'int', 'int']
#   9                  -1  1    831168  ultralytics.nn.modules.block.SPPF            [576, 576, 7]
# DEBUG: Creating Upsample with args: [None, 2, 'nearest']
# DEBUG: Arg types: ['NoneType', 'int', 'str']
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
# DEBUG: Creating Concat with args: [1]
# DEBUG: Arg types: ['int']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
# DEBUG: Creating C2f with args: [960, 384, 2, False, <class 'ultralytics.nn.modules.custom_modules.ConvSE'>]
# DEBUG: Arg types: ['int', 'int', 'int', 'bool', 'type']
#  12                  -1  2   1339032  ultralytics.nn.modules.block.C2f             [960, 384, 2, False, <class 'ultralytics.nn.modules.custom_modules.ConvSE'>]
# DEBUG: Creating Upsample with args: [None, 2, 'nearest']
# DEBUG: Arg types: ['NoneType', 'int', 'str']
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
# DEBUG: Creating Concat with args: [1]
# DEBUG: Arg types: ['int']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
# DEBUG: Creating C2f with args: [576, 192, 2, False, <class 'ultralytics.nn.modules.custom_modules.ConvSE'>]
# DEBUG: Arg types: ['int', 'int', 'int', 'bool', 'type']
#  15                  -1  2    353868  ultralytics.nn.modules.block.C2f             [576, 192, 2, False, <class 'ultralytics.nn.modules.custom_modules.ConvSE'>]
# DEBUG: Creating Upsample with args: [None, 2, 'nearest']
# DEBUG: Arg types: ['NoneType', 'int', 'str']
#  16                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
# DEBUG: Creating Concat with args: [1]
# DEBUG: Arg types: ['int']
#  17             [-1, 2]  1         0  ultralytics.nn.modules.conv.Concat           [1]
# DEBUG: Creating C2f with args: [288, 96, 1, False, <class 'ultralytics.nn.modules.custom_modules.ConvSE'>]
# DEBUG: Arg types: ['int', 'int', 'int', 'bool', 'type']
#  18                  -1  1     63027  ultralytics.nn.modules.block.C2f             [288, 96, 1, False, <class 'ultralytics.nn.modules.custom_modules.ConvSE'>]
# DEBUG: Creating ConvSE with args: [96, 96, 3, 2]
# DEBUG: Arg types: ['int', 'int', 'int', 'int']
#  19                  -1  1     84390  ultralytics.nn.modules.custom_modules.ConvSE [96, 96, 3, 2]
# DEBUG: Creating Concat with args: [1]
# DEBUG: Arg types: ['int']
#  20            [-1, 15]  1         0  ultralytics.nn.modules.conv.Concat           [1]
# DEBUG: Creating C2f with args: [288, 192, 1, False, <class 'ultralytics.nn.modules.custom_modules.ConvSE'>]
# DEBUG: Arg types: ['int', 'int', 'int', 'bool', 'type']
#  21                  -1  1    195750  ultralytics.nn.modules.block.C2f             [288, 192, 1, False, <class 'ultralytics.nn.modules.custom_modules.ConvSE'>]
# DEBUG: Creating ConvSE with args: [192, 192, 3, 2]
# DEBUG: Arg types: ['int', 'int', 'int', 'int']
#  22                  -1  1    336972  ultralytics.nn.modules.custom_modules.ConvSE [192, 192, 3, 2]
# DEBUG: Creating Concat with args: [1]
# DEBUG: Arg types: ['int']
#  23            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
# DEBUG: Creating C2f with args: [576, 384, 1, False, <class 'ultralytics.nn.modules.custom_modules.ConvSE'>]
# DEBUG: Arg types: ['int', 'int', 'int', 'bool', 'type']
#  24                  -1  1    780876  ultralytics.nn.modules.block.C2f             [576, 384, 1, False, <class 'ultralytics.nn.modules.custom_modules.ConvSE'>]
# DEBUG: Creating ConvSE with args: [384, 384, 3, 2]
# DEBUG: Arg types: ['int', 'int', 'int', 'int']
#  25                  -1  1   1346712  ultralytics.nn.modules.custom_modules.ConvSE [384, 384, 3, 2]
# DEBUG: Creating Concat with args: [1]
# DEBUG: Arg types: ['int']
#  26             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
# DEBUG: Creating C2f with args: [960, 576, 1, False, <class 'ultralytics.nn.modules.custom_modules.ConvSE'>]
# DEBUG: Arg types: ['int', 'int', 'int', 'bool', 'type']
#  27                  -1  1   1810674  ultralytics.nn.modules.block.C2f             [960, 576, 1, False, <class 'ultralytics.nn.modules.custom_modules.ConvSE'>]
# DEBUG: Creating Detect_HailoFriendly with args: [14, [96, 192, 384, 576]]
# DEBUG: Arg types: ['int', 'list']
#  28    [18, 21, 24, 27]  1  10958088  ultralytics.nn.modules.custom_modules.Detect_HailoFriendly[14, [96, 192, 384, 576]]
# YOLOv8m_p2_se summary: 292 layers, 26,041,872 parameters, 26,041,872 gradients, 85.9 GFLOPs
#
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2573.6±1311.9 MB/s, size: 81.3 KB)
# train: Scanning /home/olegqm/manipulator_project/programs/pt_to_hef_converter/ma
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1838.8±1007.5 MB/s, size: 49.6 KB)
# val: Scanning /home/olegqm/manipulator_project/programs/pt_to_hef_converter/mani
# Plotting labels to runs/train/custom_yolo_experiment32/labels.jpg...
# optimizer: SGD(lr=0.005, momentum=0.9) with parameter groups 66 weight(decay=0.0), 130 weight(decay=0.000515625), 130 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to runs/train/custom_yolo_experiment32
# Starting training for 30 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#   0%|          | 0/2812 [00:00<?, ?it/s]/home/olegqm/manipulator_project/programs/own_yolo_architecture/venv_trainer/lib/python3.10/site-packages/torch/autograd/graph.py:824: UserWarning: adaptive_avg_pool2d_backward_cuda does not have a deterministic implementation, but you set 'torch.use_deterministic_algorithms(True, warn_only=True)'. You can file an issue at https://github.com/pytorch/pytorch/issues to help us prioritize adding deterministic support for this operation. (Triggered internally at /pytorch/aten/src/ATen/Context.cpp:93.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#        1/30      6.54G      3.487       4.74          0         63        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       3664       6307      0.802     0.0251     0.0171    0.00424
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#   0%|          | 0/2812 [00:00<?, ?it/s]/home/olegqm/manipulator_project/programs/own_yolo_architecture/venv_trainer/lib/python3.10/site-packages/torch/autograd/graph.py:824: UserWarning: adaptive_avg_pool2d_backward_cuda does not have a deterministic implementation, but you set 'torch.use_deterministic_algorithms(True, warn_only=True)'. You can file an issue at https://github.com/pytorch/pytorch/issues to help us prioritize adding deterministic support for this operation. (Triggered internally at /pytorch/aten/src/ATen/Context.cpp:93.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#        2/30      6.43G      2.717      4.458          0         37        640:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 60
#      58 if __name__ == "__main__":
#      59     model = YOLO(model_cfg)
# ---> 60     model.train(data=data_cfg, **train_args)
#
# File ~/manipulator_project/programs/own_yolo_architecture/ultralytics_custom/ultralytics/engine/model.py:799, in Model.train(self, trainer, **kwargs)
#     796     self.model = self.trainer.model
#     798 self.trainer.hub_session = self.session  # attach optional HUB session
# --> 799 self.trainer.train()
#     800 # Update model and cfg after training
#     801 if RANK in {-1, 0}:
#
# File ~/manipulator_project/programs/own_yolo_architecture/ultralytics_custom/ultralytics/engine/trainer.py:227, in BaseTrainer.train(self)
#     224         ddp_cleanup(self, str(file))
#     226 else:
# --> 227     self._do_train(world_size)
#
# File ~/manipulator_project/programs/own_yolo_architecture/ultralytics_custom/ultralytics/engine/trainer.py:406, in BaseTrainer._do_train(self, world_size)
#     404 with autocast(self.amp):
#     405     batch = self.preprocess_batch(batch)
# --> 406     loss, self.loss_items = self.model(batch)
#     407     self.loss = loss.sum()
#     408     if RANK != -1:
#
# File ~/manipulator_project/programs/own_yolo_architecture/venv_trainer/lib/python3.10/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File ~/manipulator_project/programs/own_yolo_architecture/venv_trainer/lib/python3.10/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File ~/manipulator_project/programs/own_yolo_architecture/ultralytics_custom/ultralytics/nn/tasks.py:140, in BaseModel.forward(self, x, *args, **kwargs)
#     126 """
#     127 Perform forward pass of the model for either training or inference.
#     128
#    (...)
#     137     (torch.Tensor): Loss if x is a dict (training), or network predictions (inference).
#     138 """
#     139 if isinstance(x, dict):  # for cases of training and validating while training.
# --> 140     return self.loss(x, *args, **kwargs)
#     141 return self.predict(x, *args, **kwargs)
#
# File ~/manipulator_project/programs/own_yolo_architecture/ultralytics_custom/ultralytics/nn/tasks.py:339, in BaseModel.loss(self, batch, preds)
#     336 if getattr(self, "criterion", None) is None:
#     337     self.criterion = self.init_criterion()
# --> 339 preds = self.forward(batch["img"]) if preds is None else preds
#     340 return self.criterion(preds, batch)
#
# File ~/manipulator_project/programs/own_yolo_architecture/ultralytics_custom/ultralytics/nn/tasks.py:141, in BaseModel.forward(self, x, *args, **kwargs)
#     139 if isinstance(x, dict):  # for cases of training and validating while training.
#     140     return self.loss(x, *args, **kwargs)
# --> 141 return self.predict(x, *args, **kwargs)
#
# File ~/manipulator_project/programs/own_yolo_architecture/ultralytics_custom/ultralytics/nn/tasks.py:159, in BaseModel.predict(self, x, profile, visualize, augment, embed)
#     157 if augment:
#     158     return self._predict_augment(x)
# --> 159 return self._predict_once(x, profile, visualize, embed)
#
# File ~/manipulator_project/programs/own_yolo_architecture/ultralytics_custom/ultralytics/nn/tasks.py:182, in BaseModel._predict_once(self, x, profile, visualize, embed)
#     180 if profile:
#     181     self._profile_one_layer(m, x, dt)
# --> 182 x = m(x)  # run
#     183 y.append(x if m.i in self.save else None)  # save output
#     184 if visualize:
#
# File ~/manipulator_project/programs/own_yolo_architecture/venv_trainer/lib/python3.10/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File ~/manipulator_project/programs/own_yolo_architecture/venv_trainer/lib/python3.10/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File ~/manipulator_project/programs/own_yolo_architecture/ultralytics_custom/ultralytics/nn/modules/custom_modules.py:88, in Detect_HailoFriendly.forward(self, x)
#      86     return outputs
#      87 for i in range(self.nl):
# ---> 88     x[i] = torch.cat((self.cv2[i](x[i]), self.cv3[i](x[i])), 1)
#      89 if self.training:
#      90     return x
#
# File ~/manipulator_project/programs/own_yolo_architecture/venv_trainer/lib/python3.10/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File ~/manipulator_project/programs/own_yolo_architecture/venv_trainer/lib/python3.10/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File ~/manipulator_project/programs/own_yolo_architecture/venv_trainer/lib/python3.10/site-packages/torch/nn/modules/container.py:240, in Sequential.forward(self, input)
#     238 def forward(self, input):
#     239     for module in self:
# --> 240         input = module(input)
#     241     return input
#
# File ~/manipulator_project/programs/own_yolo_architecture/venv_trainer/lib/python3.10/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File ~/manipulator_project/programs/own_yolo_architecture/venv_trainer/lib/python3.10/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File ~/manipulator_project/programs/own_yolo_architecture/ultralytics_custom/ultralytics/nn/modules/conv.py:80, in Conv.forward(self, x)
#      70 def forward(self, x):
#      71     """
#      72     Apply convolution, batch normalization and activation to input tensor.
#      73
#    (...)
#      78         (torch.Tensor): Output tensor.
#      79     """
# ---> 80     return self.act(self.bn(self.conv(x)))
#
# KeyboardInterrupt:
